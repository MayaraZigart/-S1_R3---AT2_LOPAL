# %% [markdown]
# <a href="https://colab.research.google.com/github/MayaraZigart/-S1_R3---AT2_LOPAL/blob/main/exercic%C3%ADos_morato.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## numeros pares e impares de 0 a 100

# %%
#Exercicío 1
print("numeros pares:")
for i in range(101):
    if i % 2 == 0:
        print(i, end=", ")

print("\n\nnumeros impares:")
for i in range(101):
    if i % 2 != 0:
        print(i, end=", ")

# %%
#Exercicío 2
numeros = []

for i in range(3):
    numero = float(input("digite um numero: "))
    numeros.append(numero)

maior = max(numeros)
menor = min(numeros)

print("maior numero:", maior)
print("menor numero:", menor)
# Out:
# digite um numero: 6
# digite um numero: 7
# digite um numero: 8
# maior numero: 8.0
# menor numero: 6.0

# %%
#Exercicío 3
nome = input("Digite seu nome: ")

for i in range(1, len(nome) +1):

  print(nome[:i])
# Out:
# Digite seu nome: maayara
# m
# ma
# maa
# maay
# maaya
# maayar
# maayara

# %%
#exercicío 4
n = int(input("digite um número: "))

a = 1
b = 1

print(a)
print(b)

for i in range(n - 2):
    c = a + b
    print(c)

    a = b
    b = c
# Out:
# digite um número: 7
# 1
# 1
# 2
# 3
# 5
# 8
# 13

# %%
#exercicío 5
nome = input("digite seu nome: ")

while len(nome) <= 3:
    nome = input("nome invalido, digite novamente: ")

idade = int(input("digite sua idade: "))

while idade < 0 or idade > 150:
    idade = int(input("idade invalida, digite novamente: "))

salario = float(input("digite seu salario: "))

while salario <= 0:
    salario = float(input("salario invalido, digite novamente: "))

sexo = input("digite seu sexo: ")

while sexo != "f" and sexo != "m":
    sexo = input("sexo invalido, digite novamente: ")

estado = input("digite seu estado civil: ")

while estado != "s" and estado != "c" and estado != "v" and estado != "d":
    estado = input("estado civil invalido, digite novamente: ")

print("dados validos")
# Out:
# digite seu nome: mayara
# digite sua idade: 16
# digite seu salario: 2500
# digite seu sexo: feminino
# sexo invalido, digite novamente: f
# digite seu estado civil: namorando
# estado civil invalido, digite novamente: s
# dados validos

# %%
#Exercicío 6
numero = int(input("digite um numero: "))

contador = 0

for i in range(1, numero + 1):
    if numero % i == 0:
        contador = contador + 1

if contador == 2:
    print("o numero é primo")
else:
    print("o numero nao é primo")

# %%
#Exercicío 7
numero = int(input("digite um numero: "))

fatorial = 1

for i in range(1, numero + 1):
    fatorial = fatorial * i

print("o fatorial é:", fatorial)

# %%
#Exercicío 8
l = [5, 7, 2, 9, 4, 1, 3]

print(len(l))
print(max(l))
print(min(l))
print(sum(l))

l.sort()
print(l)

l.sort(reverse=True)
print(l)
# Out:
# 7
# 9
# 1
# 31
# [1, 2, 3, 4, 5, 7, 9]
# [9, 7, 5, 4, 3, 2, 1]

# %%
#Exercicío 9
lanchonete = {
    "salgado": 4.50,
    "lanche": 6.50,
    "suco": 3.00,
    "refrigerante": 3.50,
    "doce": 1.00
}

print(lanchonete)

# %%
#Exercicío 10
senha = 676767

numero = 0

while numero != senha:
    numero = int(input("digite a senha: "))

print("acesso liberado")
# Out:
# digite a senha: 676767
# acesso liberado

# %%
#Exercicío 11
numero = int(input("digite um numero de 1 a 10: "))

for i in range(1, 11):
    print(numero, "x", i, "=", numero * i)
